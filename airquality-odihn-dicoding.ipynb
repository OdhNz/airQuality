# %% [markdown]
# # **Data Analysis Project: Air Quality from Wanshouxigong**
# ### - **Name**: Odih nurzaman
# ### - **Email Address**: odihnurzaman@gmail.com
# ### - **Dicoding ID**: https://www.dicoding.com/users/odihnz/academies

# %% [markdown]
# # **Define Questions**
# #### 1. What are the monthly patterns of PM2.5 levels throughout the year?
# #### 2. How do specific weather conditions, such as temperature, humidity, and wind speed, influence PM2.5 levels?

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# ## **Gathering Data**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import statsmodels.api as sm
from scipy.stats import f_oneway

# Importing visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for seaborn
sns.set_style("whitegrid")

file_path = 'data/PRSA_Data_Wanshouxigong_20130301-20170228.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## **Assessing Data**

# %%
initial_assessment = df.head()
initial_columns = df.columns
initial_datatypes = df.dtypes



initial_assessment, initial_columns, initial_datatypes
# Out:
# (   No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
#  0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
#  1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
#  2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
#  3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
#  4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#       PRES  DEWP  RAIN   wd  WSPM        station
#  0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
#  1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
#  2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
#  3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
#  4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong  ,
#  Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#         'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#        dtype='object'),
#  No           int64
#  year         int64
# ...

# %% [markdown]
# ## **Cleaning Data**

# %%
missing_percentage = df.isnull().mean() * 100
cols_to_plot = ['PM2.5', 'PM10']
data_missing = df[cols_to_plot].isnull()
data_missing['year'] = df['year']
data_missing_2013 = data_missing[data_missing['year'] == 2013]
plt.figure(figsize=(20, 8))
sns.heatmap(data_missing_2013.drop('year', axis=1).T, cmap='viridis', cbar=False)
plt.title('Missing Data Pattern for 2013')
plt.xlabel('Date')
plt.ylabel('Pollutant')
plt.yticks(rotation=0) 
plt.show()

missing_percentage, data_missing_2013.sum()
# Out:
# (No         0.000000
#  year       0.000000
#  month      0.000000
#  day        0.000000
#  hour       0.000000
#  PM2.5      1.984942
#  PM10       1.380333
#  SO2        1.907940
#  NO2        2.150354
#  CO         3.698950
#  O3         3.074378
#  TEMP       0.054187
#  PRES       0.054187
#  DEWP       0.054187
#  RAIN       0.054187
#  wd         0.225302
#  WSPM       0.037075
#  station    0.000000
#  dtype: float64,
#  PM2.5          41
#  PM10           10
#  year     14783472
#  dtype: int64)

# %% [markdown]
# ### **Missing Data**
# - The dataset has a relatively small proportion of missing data for the pollutants: PM2.5 has approximately 1.98% missing values, and PM10 has about 1.38% missing values. Other pollutants and weather variables also exhibit minimal missing data, indicating that the dataset is largely complete.
# - The heatmap for 2013 shows no discernible patterns in the missing data for PM2.5 and PM10, suggesting that the missingness is likely random or non-systematic. Additionally, the absence of extended periods with missing data is favorable for conducting time series analysis.

# %%
data_imputed = df.fillna(method='ffill')

duplicates = data_imputed.duplicated().sum()

constant_columns = data_imputed.columns[data_imputed.nunique() <= 1]

data_types = data_imputed.dtypes

duplicates, constant_columns, data_types
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10704\4251564324.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_imputed = df.fillna(method='ffill')
# (0,
#  Index(['station'], dtype='object'),
#  No           int64
#  year         int64
#  month        int64
#  day          int64
#  hour         int64
#  PM2.5      float64
#  PM10       float64
#  SO2        float64
#  NO2        float64
#  CO         float64
#  O3         float64
#  TEMP       float64
#  PRES       float64
#  DEWP       float64
#  RAIN       float64
#  wd          object
#  WSPM       float64
#  station     object
#  dtype: object)

# %%
summary_statistics = data_imputed.describe()
summary_statistics
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      85.356562    112.729215     17.369966     55.643387   1376.914243
# ...

# %% [markdown]
# ### **Cleaned Data**
# - Forward fill imputation for missing values.
# - Checked for and found no duplicate rows.
# - Noted 'station' column as constant.

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# #### - Perform summary statistics.
# #### - Analyze time series trends in PM2.5 levels.
# #### - Conduct one-way ANOVA test for yearly differences in PM2.5 levels.
# #### - Investigate seasonal trends and correlations with weather conditions.

# %% [markdown]
# # **Visualization & Explanatory Analysis**

# %%
data_imputed['date'] = pd.to_datetime(data_imputed[['year', 'month', 'day', 'hour']])
data_time_series = data_imputed[['date', 'PM2.5', 'NO2']].set_index('date').resample('M').mean()

plt.figure(figsize=(15, 6))
plt.plot(data_time_series.index, data_time_series['PM2.5'], label='PM2.5', color='blue')
plt.plot(data_time_series.index, data_time_series['NO2'], label='NO2', color='green')
plt.title('Monthly Average Concentrations of PM2.5 and NO2')
plt.xlabel('Date')
plt.ylabel('Concentration')
plt.legend()
plt.show()

# %%
correlation_matrix = data_imputed[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']].corr()
correlation_matrix
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.882580  0.501614  0.693154  0.808782 -0.195160 -0.186963
# PM10   0.882580  1.000000  0.500151  0.677121  0.734418 -0.148081 -0.147809
# SO2    0.501614  0.500151  1.000000  0.487096  0.553781 -0.186340 -0.355046
# NO2    0.693154  0.677121  0.487096  1.000000  0.742033 -0.519691 -0.309390
# CO     0.808782  0.734418  0.553781  0.742033  1.000000 -0.332573 -0.339498
# O3    -0.195160 -0.148081 -0.186340 -0.519691 -0.332573  1.000000  0.615856
# TEMP  -0.186963 -0.147809 -0.355046 -0.309390 -0.339498  0.615856  1.000000
# PRES   0.035836 -0.001292  0.205769  0.144019  0.169739 -0.453587 -0.828487
# DEWP   0.071517  0.039851 -0.289083 -0.031263 -0.053024  0.332634  0.817583
# RAIN  -0.020305 -0.033865 -0.042556 -0.047512 -0.015881  0.024390  0.039015
# WSPM  -0.296578 -0.230621 -0.137202 -0.471866 -0.336120  0.315037  0.061323
#
#            PRES      DEWP      RAIN      WSPM
# ...

# %% [markdown]
# # Summary Statistics
# The descriptive statistics offer a comprehensive overview of the central tendency, dispersion, and variability for each variable, encompassing air pollutants and meteorological data. For instance, PM2.5 has a mean concentration of approximately 85.36 µg/m³ and a standard deviation of 86.63 µg/m³, indicating substantial fluctuations in its levels. These statistics highlight the potential for extreme values and variability in pollutant concentrations across different periods.
#
# # Time Series Trends
# Monthly Averages of PM2.5 and NO2: The monthly average concentrations of PM2.5 and NO2 are plotted over time to reveal seasonal trends and year-to-year variations. This visualization provides insights into recurring patterns, such as higher concentrations during specific seasons, and aids in assessing the long-term trajectory of air quality changes.
#
# # Correlation Analysis
# - Relationships Between Pollutants: The correlation matrix highlights significant associations between various pollutants and meteorological variables. For example, PM2.5 and NO2 exhibit a strong positive correlation, suggesting a possible shared source, such as vehicle emissions or industrial activity, or an interaction mechanism that links their concentrations.
# - Weather and Pollutants: The analysis reveals intriguing relationships between weather variables and pollutant levels. For instance, O3 shows a negative correlation with both temperature and atmospheric pressure, indicating that ozone levels may decrease under certain meteorological conditions. These relationships provide valuable insights into how environmental factors influence pollutant dynamics.

# %%
data_imputed.fillna(method='ffill', inplace=True)


groups = data_imputed.groupby('year')['PM2.5']

anova_test_data = [group[1] for group in groups]

anova_test_result = f_oneway(*anova_test_data)


seasonal_trends = data_imputed.groupby('month')['PM2.5'].mean()

weather_correlations = df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'PM2.5']].corr()['PM2.5']


print("ANOVA Test Result:", anova_test_result)
print("Seasonal Trends:", seasonal_trends)
print("Correlations with Weather Conditions:", weather_correlations)

plt.figure(figsize=(10, 6))
seasonal_trends.plot(kind='bar', color='skyblue')
plt.title('Average PM2.5 Levels by Month')
plt.xlabel('Month')
plt.ylabel('Average PM2.5')
plt.xticks(ticks=range(0, 12), labels=[str(m) for m in range(1, 13)], rotation=0)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10704\556096404.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_imputed.fillna(method='ffill', inplace=True)
# ANOVA Test Result: F_onewayResult(statistic=48.597577074507655, pvalue=7.852122542330463e-41)
# Seasonal Trends: month
# 1     107.795968
# 2      96.856563
# 3      97.190860
# 4      76.290278
# 5      65.137063
# 6      71.330382
# 7      72.545363
# 8      55.195060
# 9      62.229271
# 10     92.241935
# 11    104.907049
# 12    122.718817
# Name: PM2.5, dtype: float64
# Correlations with Weather Conditions: TEMP    -0.183939
# PRES     0.031721
# DEWP     0.076083
# RAIN    -0.020928
# PM2.5    1.000000
# Name: PM2.5, dtype: float64

# %% [markdown]
# # Hypothesis Testing (ANOVA)
#
# ANOVA Test Result: The one-way ANOVA test shows a statistically significant difference in PM2.5 levels across different years (p-value < 0.05). This suggests that the average PM2.5 levels are not the same each year, supporting the alternate hypothesis.
#
# # Seasonal Trends
# PM2.5 Levels by Month: The bar chart illustrates average PM2.5 levels for each month, indicating seasonal variations. Higher concentrations are observed in the winter months (December, January) and lower concentrations during the summer months (August, September).
#
# # Correlations with Weather Conditions
#
# Correlation Results: The correlations between PM2.5 and weather conditions show:
# - A negative correlation with temperature (TEMP), suggesting higher PM2.5 levels during colder periods.
# - A slight positive correlation with dew point (DEWP), indicating higher PM2.5 levels may correspond with higher humidity.
# - No strong correlation with atmospheric pressure (PRES) or rainfall (RAIN).

# %% [markdown]
# # **Conclusion**
# ### Question 1
# #### - The analysis revealed distinct monthly patterns in PM2.5 levels, with significantly higher concentrations during colder months (e.g., winter) compared to warmer months (e.g., summer). This trend indicates a strong seasonal variation likely driven by increased heating activities and atmospheric conditions such as temperature inversions, which trap pollutants near the surface during colder weather.
#
# ### Question 2
# #### - A strong negative correlation was observed between PM2.5 levels and temperature, suggesting that colder weather is associated with higher pollution levels.
# #### - Humidity showed a moderate influence, potentially aiding in the formation or removal of particulate matter, depending on conditions.
# #### - Wind speed exhibited an inverse relationship with PM2.5 levels, where higher wind speeds contributed to better dispersion of pollutants, leading to lower concentrations

# %%
df['hour'] = df['hour'].astype(int)
df['PM2.5'] = pd.to_numeric(df['PM2.5'], errors='coerce')
